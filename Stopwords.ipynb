# %%
import re
import pandas as pd
import numpy as np

# Silence warnings
import warnings
warnings.filterwarnings("ignore")
pd.options.mode.chained_assignment = None

# %%
def read_txt(name):
    
    f = open("txt/" + name + ".txt", "r")
    text = f.read()
    f.close()
    
    return text

# %%
Homer_raw = read_txt('odyssey_Homer') + read_txt('iliad_Homer')
Others_raw = read_txt('aristides') + read_txt('hesiode') \
    + read_txt('lycurgus') + read_txt('aristotle') \
    + read_txt('antiphon') + read_txt('thucydides')

# %%
df_betunicode = pd.read_csv('lem/betunicode_gr.csv', delimiter = ';')
df_betunicode.head()
# Out:
#    match    code transcript     indice  \
# 0  *)\|a  U+1F8A          ᾊ  225190138
# 1  *(\|a  U+1F8B          ᾋ  225190139
# 2  *)/|a  U+1F8C          ᾌ  225190140
# 3  *(/|a  U+1F8D          ᾍ  225190141
# 4  *)=|a  U+1F8E          ᾎ  225190142
#
#                                              comment
# 0  GREEK CAPITAL LETTER ALPHA WITH PSILI AND VARI...
# 1  GREEK CAPITAL LETTER ALPHA WITH DASIA AND VARI...
# 2  GREEK CAPITAL LETTER ALPHA WITH PSILI AND OXIA...
# 3  GREEK CAPITAL LETTER ALPHA WITH DASIA AND OXIA...
# 4  GREEK CAPITAL LETTER ALPHA WITH PSILI AND PERI...

# %%
stopwords = ['a)/llos', 'a)/n', 'a)/ra', 'a)ll', 'a)lla/', 'a)po/', 'au)to/s', 
             "d᾽", 'dai/', 'dai/s', 'de/', 'dh/', 'dia/', 'e(autou=', 'e)/ti', 
             'e)a/n', 'e)gw/', 'e)k', 'e)mo/s', 'e)n', 'e)pi/', 'ei)', 'ei)/mi', 
             'ei)mi/', 'ei)s', 'ga/r', 'ga^', 'ge', 'h(', 'h)/', 'kai/', 'kata/', 
             'me/n', 'meta/', 'mh/', 'o(', 'o(/de', 'o(/s', 'o(/stis', 'o(/ti', 
             'oi(', 'ou(/tws', 'ou(=tos', 'ou)', 'ou)/te', 'ou)=n', 'ou)de/', 
             'ou)dei/s', 'ou)k', 'para/', 'peri/', 'pro/s', 'so/s', 'su/', 'su/n',
             'ta/', 'te', 'th/n', 'th=s', 'th=|', 'ti', 'ti/', 'ti/s', 'tis',
             'to/', 'to/n', 'toi/', 'toiou=tos', 'tou/s', 'tou=', 'tw=n', 'tw=|', 
             'u(mo/s', 'u(pe/r', 'u(po/', 'w(/ste', 'w(s', 'w)=']

# %%
stopwords_gr = []

for stopword in stopwords:
    
    new_word = stopword
    
    for ind, row in df_betunicode.iterrows():
        new_word = new_word.replace(row['match'], row['transcript'])
            
    stopwords_gr.append(new_word)

# %%
stopwords_gr[:5]
# Out:
# ['ἄλλοσ', 'ἄν', 'ἄρα', 'ἀλλ', 'ἀλλά']

# %%
df_Homer_raw = pd.read_csv('metrics/df_Homer_raw.csv').drop(columns = 'Unnamed: 0')
df_Others_raw = pd.read_csv('metrics/df_Others_raw.csv').drop(columns = 'Unnamed: 0')

# %%
df_Homer_raw.head()
# Out:
#   word  count  length  weighted_MSE  weighted_MAE       std
# 0  NaN  41741       0   1742.311081        41.741  0.000000
# 1  καὶ   4803       3      0.038809         0.197  1.890555
# 2    δ   3672       1     13.483584         3.672  0.000000
# 3   δὲ   3188       2      1.411344         1.188  1.632696
# 4   δ᾽   2823       2     10.093329         3.177  2.369936

# %%
list_H, list_O = [], []

for stopword in stopwords_gr:
    
    n = df_Homer_raw[df_Homer_raw['word'] == stopword].index.values.tolist()
    m = df_Others_raw[df_Others_raw['word'] == stopword].index.values.tolist()
    
    if len(n) > 0:
        list_H.append(n[0])
    
    if len(m) > 0:
        list_O.append(m[0])
        
df_Homer = df_Homer_raw.iloc[list_H].drop(columns = ['length', 'weighted_MAE'])
df_Others = df_Others_raw.iloc[list_O].drop(columns = ['length', 'weighted_MAE'])

# %%
df_merge = pd.merge(df_Homer, df_Others, on = 'word', how = 'outer')
ratio = 0.525

# %%
df_merge['count_ratio'] = df_merge['count_x'] / (ratio * df_merge['count_y'])

# %%
df_merge.sort_values('count_ratio', ascending = False)
# Out:
#       word  count_x  weighted_MSE_x     std_x  count_y  weighted_MSE_y  \
# 13     ὅδε     23.0        0.000529  0.000000      7.0        0.000013
# 1      ἄρα    575.0        0.330625  0.400000    186.0        0.818329
# 11       ἤ    100.0        0.010000  0.000000     34.0        0.000304
# 3       δ᾽   2823.0       10.093329  2.369936   3329.0        0.500103
# 9       γε    628.0        0.138384  0.793080    927.0        0.225991
# 21      τε   2649.0        5.527201  1.644761   4628.0        0.392711
# 23      τι    408.0        0.166464  0.769415   1043.0        0.286088
# 4      ἔτι    220.0        0.048400  0.000000    618.0        0.100440
# 16      οἱ   1129.0        8.242641  1.476524   3189.0        2.674483
# 6       ἐν   1408.0        0.350464  0.996248   3996.0        0.002424
# 28       ὦ    138.0        0.019044  0.000000    393.0        0.040618
# 5       ἐκ    555.0        0.308025  0.489898   1595.0        0.033143
# 17      οὐ    533.0        0.284089  0.490697   2016.0        3.865761
# 7       εἰ    392.0        0.153664  0.448013   1506.0        0.051844
# 20     οὐκ    369.0        0.136161  0.000000   1737.0        4.448854
# 18    οὔτε    125.0        0.015625  0.000000    656.0        0.113172
# 0       ἄν     48.0        0.002304  0.000000    290.0        0.022117
# 26      τῷ    329.0        0.450241  0.464913   2222.0        0.019457
# 12       ὁ    301.0        7.284601  0.941401   2179.0        1.248663
# 10       ἡ    146.0        0.021316  0.400000   1487.0        1.531248
# 19     οὖν     85.0        0.007225  0.000000    901.0        0.289389
# 24     τοῦ    227.0        0.051529  0.657358   3546.0        4.759110
# 22      τῇ    126.0        0.015876  0.000000   2012.0        1.064601
# 25     τῶν    262.0        0.544644  0.441864   6429.0       10.869702
# 15     ὅτι     42.0        0.001764  0.000000   1114.0        0.326363
# 27    ὥστε      1.0        0.000001  0.000000    583.0        0.089386
# 2      ἀλλ    478.0        0.228484  0.000000      NaN             NaN
# 8      εἰσ      8.0        0.000064  0.000000      NaN             NaN
# 14      ὅσ      6.0        0.000036  0.000000      NaN             NaN
# 29  ἑαυτοῦ      NaN             NaN       NaN    181.0        0.008616
#
#        std_y  count_ratio
# 13  0.348048     6.258503
# 1   0.641527     5.888377
# 11  0.000000     5.602241
# 3   0.626950     1.615243
# 9   0.641784     1.290389
# 21  2.870864     1.090258
# 23  0.394057     0.745103
# 4   0.303389     0.678071
# 16  0.739298     0.674342
# 6   1.135677     0.671147
# 28  0.365652     0.668848
# 5   0.947109     0.662785
# 17  1.380002     0.503590
# 7   0.397674     0.495795
# 20  0.828263     0.404639
# 18  0.803772     0.362950
# 0   0.303389     0.315271
# 26  0.736398     0.282028
# 12  0.782350     0.263118
# 10  0.609826     0.187018
# 19  0.628405     0.179695
# 24  1.628943     0.121935
# 22  0.671462     0.119284
# 25  1.587045     0.077624
# 15  0.469747     0.071813
# 27  0.063920     0.003267
# 2        NaN          NaN
# 8        NaN          NaN
# 14       NaN          NaN
# 29  0.303389          NaN

# %%
eng = read_txt('Iliad_RL')
